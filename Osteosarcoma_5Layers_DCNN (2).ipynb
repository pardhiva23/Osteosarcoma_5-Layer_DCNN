#   inflating: dataset/validate/Viable/Case-4-C29-23938-15097.jpg
#   inflating: dataset/validate/Viable/Case-4-C29-24903-19562.jpg
#   inflating: dataset/validate/Viable/Case-4-C29-30319-13766.jpg
#   inflating: dataset/validate/Viable/Case-4-C29-31670-19505.jpg
#   inflating: dataset/validate/Viable/Case-4-C31-24654-15629.jpg
#   inflating: dataset/validate/Viable/Case-4-C31-24669-10300.jpg
#   inflating: dataset/validate/Viable/Case-4-C31-25176-8074.jpg
#   inflating: dataset/validate/Viable/Case-4-C31-30577-21392.jpg
#   inflating: dataset/validate/Viable/Case-4-C31-35324-16735.jpg
#   inflating: dataset/validate/Viable/Case-4-C31-41557-17880.jpg
#   inflating: dataset/validate/Viable/Case-4-C34-23917-10671.jpg
#   inflating: dataset/validate/Viable/Case-4-C34-24821-20023.jpg
#   inflating: dataset/validate/Viable/Case-4-C34-25269-6322.jpg
#   inflating: dataset/validate/Viable/Case-4-C34-28567-20375.jpg
#   inflating: dataset/validate/Viable/Case-4-C34-30175-9259.jpg
#   inflating: dataset/validate/Viable/Case-4-C34-33534-16910.jpg
#   inflating: dataset/validate/Viable/Case-4-C34-38608-21388.jpg
#   inflating: dataset/validate/Viable/Case-48-P5-C13-28480-4550.jpg
#   inflating: dataset/validate/Viable/Case-48-P5-C13-33156-9373.jpg
#   inflating: dataset/validate/Viable/Case-48-P5-C13-35186-4450.jpg
#   inflating: dataset/validate/Viable/Case-48-P5-C13-35786-2519.jpg
#   inflating: dataset/validate/Viable/Case-48-P5-C13-36274-5595.jpg
#   inflating: dataset/validate/Viable/Case-48-P5-C13-36431-2977.jpg
#   inflating: dataset/validate/Viable/Case-48-P5-C13-40217-4387.jpg
#   inflating: dataset/validate/Viable/Case-48-P5-C13-45972-4022.jpg
#   inflating: dataset/validate/Viable/Case-48-P5-C13-47517-9280.jpg
#   inflating: dataset/validate/Viable/Case-48-P5-C13-47829-6226.jpg
#   inflating: dataset/validate/Viable/Case-48-P5-C13-64007-12122.jpg
#   inflating: dataset/validate/Viable/Case-48-P5-C14-29041-7944.jpg
#   inflating: dataset/validate/Viable/Case-48-P5-C14-32278-10661.jpg
#   inflating: dataset/validate/Viable/Case-48-P5-C14-39467-6941.jpg
#   inflating: dataset/validate/Viable/Case-48-P5-C14-41089-9651.jpg
#   inflating: dataset/validate/Viable/Case-48-P5-C14-44941-18452.jpg
#   inflating: dataset/validate/Viable/Case-48-P5-C14-50416-27346.jpg
#   inflating: dataset/validate/Viable/Case-48-P5-C14-50604-21283.jpg
#   inflating: dataset/validate/Viable/Case-48-P5-C14-52144-3660.jpg
#   inflating: dataset/validate/Viable/Case-48-P5-C14-56563-30345.jpg
#   inflating: dataset/validate/Viable/Case-48-P5-C14-59148-13815.jpg
#   inflating: dataset/validate/Viable/Case-48-P5-C14-59834-18325.jpg
#   inflating: dataset/validate/Viable/Case-48-P5-C14-65736-13805.jpg
#   inflating: dataset/validate/Viable/Case-48-P5-C14-67137-24045.jpg
#   inflating: dataset/validate/Viable/Case-48-P5-C15-15457-16306.jpg
#   inflating: dataset/validate/Viable/Case-48-P5-C15-18011-21615.jpg
#   inflating: dataset/validate/Viable/Case-48-P5-C15-23409-12305.jpg
#   inflating: dataset/validate/Viable/Case-48-P5-C15-25805-11251.jpg
#   inflating: dataset/validate/Viable/Case-48-P5-C15-9871-11637.jpg

# %%
# !pip install tensorflow matplotlib scikit-learn seaborn -q

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import (
    Conv2D, SeparableConv2D, BatchNormalization,
    MaxPooling2D, GlobalAveragePooling2D,
    Add, Dropout, Dense, Activation, Multiply, Reshape
)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
import json

print("TF:", tf.__version__)
# Out:
# TF: 2.19.0

# %%
DATASET_PATH = "/content/dataset"
CLASS_NAMES  = ['Non-Tumor', 'Non-Viable-Tumor', 'Viable']
IMG_SIZE     = (224, 224)
BATCH_SIZE   = 16
EPOCHS       = 60
NUM_CLASSES  = 3
LR           = 3e-4

# %%
train_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.15,
    height_shift_range=0.15,
    horizontal_flip=True,
    vertical_flip=True,
    zoom_range=0.15,
    shear_range=0.1,
    brightness_range=[0.8, 1.2],
    fill_mode='reflect'
).flow_from_directory(
    DATASET_PATH + "/train",
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    classes=CLASS_NAMES,
    shuffle=True
)

val_gen = ImageDataGenerator(
    rescale=1./255
).flow_from_directory(
    DATASET_PATH + "/validate",
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    classes=CLASS_NAMES,
    shuffle=False
)

# Class weights
cw = compute_class_weight('balanced',
                          classes=np.unique(train_gen.classes),
                          y=train_gen.classes)
class_weights = dict(enumerate(cw))

print("Train:", train_gen.samples, "| Val:", val_gen.samples)
print("Class weights:", {CLASS_NAMES[k]: round(v,3) for k,v in class_weights.items()})
# Out:
# Found 640 images belonging to 3 classes.
# Found 231 images belonging to 3 classes.
# Train: 640 | Val: 231
# Class weights: {'Non-Tumor': np.float64(0.627), 'Non-Viable-Tumor': np.float64(1.481), 'Viable': np.float64(1.368)}

# %%
def se_block(x, filters, name):
    gap   = GlobalAveragePooling2D(name=f'GAP{name}')(x)
    fc1   = Dense(filters, activation='relu',    name=f'SE1{name}')(gap)
    fc2   = Dense(filters, activation='sigmoid', name=f'SE2{name}')(fc1)
    scale = Reshape((1, 1, filters),             name=f'SER{name}')(fc2)
    return Multiply(name=f'SEM{name}')([x, scale])


def dcnn_block(x, filters, name):
    # Align channels for shortcut
    if x.shape[-1] != filters:
        x = Conv2D(filters, 1, padding='same', use_bias=False,
                   name=f'Align{name}')(x)
        x = BatchNormalization(name=f'BNA{name}')(x)

    # SE attention on shortcut
    shortcut = se_block(x, filters, name)

    # Path A: 3x3
    a = SeparableConv2D(filters, 3, padding='same', use_bias=False,
                        name=f'SC3{name}')(x)
    a = BatchNormalization(name=f'BN3{name}')(a)
    a = Activation('relu', name=f'R3{name}')(a)

    # Path B: 5x5
    b = SeparableConv2D(filters, 5, padding='same', use_bias=False,
                        name=f'SC5{name}')(x)
    b = BatchNormalization(name=f'BN5{name}')(b)
    b = Activation('relu', name=f'R5{name}')(b)

    out = Add(name=f'Add{name}')([shortcut, a, b])
    return Activation('relu', name=f'Act{name}')(out)


def build_model():
    inputs = Input(shape=(224, 224, 3))

    # Layer 1 - Stem
    x = Conv2D(32, 3, padding='same', use_bias=False)(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(2)(x)

    # Layers 2-5 — DCNN Blocks
    x = dcnn_block(x, 64,  name='1')
    x = MaxPooling2D(2)(x)

    x = dcnn_block(x, 128, name='2')
    x = MaxPooling2D(2)(x)

    x = dcnn_block(x, 256, name='3')
    x = MaxPooling2D(2)(x)

    x = dcnn_block(x, 256, name='4')
    x = MaxPooling2D(2)(x)

    # Head
    x = GlobalAveragePooling2D()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.3)(x)
    x = Dense(NUM_CLASSES, activation='softmax')(x)

    return Model(inputs, x, name='5_Layer_DCNN')


model = build_model()
model.summary()
# Out:
# Model: "5_Layer_DCNN"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 224, 224,  │        864 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 224, 224,  │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 224, 224,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 112, 112,  │          0 │ activation[0][0]  │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Align1 (Conv2D)     │ (None, 112, 112,  │      2,048 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ BNA1                │ (None, 112, 112,  │        256 │ Align1[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ GAP1                │ (None, 64)        │          0 │ BNA1[0][0]        │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ SE11 (Dense)        │ (None, 64)        │      4,160 │ GAP1[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ SE21 (Dense)        │ (None, 64)        │      4,160 │ SE11[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ SC31                │ (None, 112, 112,  │      4,672 │ BNA1[0][0]        │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ SC51                │ (None, 112, 112,  │      5,696 │ BNA1[0][0]        │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ SER1 (Reshape)      │ (None, 1, 1, 64)  │          0 │ SE21[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ BN31                │ (None, 112, 112,  │        256 │ SC31[0][0]        │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ BN51                │ (None, 112, 112,  │        256 │ SC51[0][0]        │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ SEM1 (Multiply)     │ (None, 112, 112,  │          0 │ BNA1[0][0],       │
# │                     │ 64)               │            │ SER1[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │
0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ SC34                │ (None, 14, 14,    │     67,840 │ max_pooling2d_3[… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ SC54                │ (None, 14, 14,    │     71,936 │ max_pooling2d_3[… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ SER4 (Reshape)      │ (None, 1, 1, 256) │          0 │ SE24[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ BN34                │ (None, 14, 14,    │      1,024 │ SC34[0][0]        │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ BN54                │ (None, 14, 14,    │      1,024 │ SC54[0][0]        │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ SEM4 (Multiply)     │ (None, 14, 14,    │          0 │ max_pooling2d_3[… │
# │                     │ 256)              │            │ SER4[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ R34 (Activation)    │ (None, 14, 14,    │          0 │ BN34[0][0]        │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ R54 (Activation)    │ (None, 14, 14,    │          0 │ BN54[0][0]        │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Add4 (Add)          │ (None, 14, 14,    │          0 │ SEM4[0][0],       │
# │                     │ 256)              │            │ R34[0][0],        │
# │                     │                   │            │ R54[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Act4 (Activation)   │ (None, 14, 14,    │          0 │ Add4[0][0]        │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 7, 7, 256) │          0 │ Act4[0][0]        │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ max_pooling2d_4[… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │     65,792 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 128)       │     32,896 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 3)         │        387 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 782,051 (2.98 MB)
#  Trainable params: 778,275 (2.97 MB)
#  Non-trainable params: 3,776 (14.75 KB)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(LR),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy']
)

# %%
callbacks = [
    EarlyStopping(patience=15, restore_best_weights=True,
                  monitor='val_accuracy', verbose=1),
    ReduceLROnPlateau(factor=0.5, patience=7,
                      monitor='val_loss', verbose=1, min_lr=1e-6),
    ModelCheckpoint('/content/drive/MyDrive/best_model.keras',
                    save_best_only=True, monitor='val_accuracy', verbose=1)
]

history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=EPOCHS,
    callbacks=callbacks,
    class_weight=class_weights
)
# Out:
# Epoch 1/60
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.4929 - loss: 1.5942
# Epoch 1: val_accuracy improved from None to 0.38095, saving model to /content/drive/MyDrive/best_model.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/best_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 51s 577ms/step - accuracy: 0.5594 - loss: 1.3068 - val_accuracy: 0.3810 - val_loss: 1.0951 - learning_rate: 3.0000e-04
# Epoch 2/60
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.5701 - loss: 1.0726
# Epoch 2: val_accuracy did not improve from 0.38095
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 381ms/step - accuracy: 0.6281 - loss: 0.9809 - val_accuracy: 0.3810 - val_loss: 1.0959 - learning_rate: 3.0000e-04
# Epoch 3/60
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.6546 - loss: 0.8539
# Epoch 3: val_accuracy did not improve from 0.38095
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 368ms/step - accuracy: 0.6656 - loss: 0.8653 - val_accuracy: 0.3810 - val_loss: 1.1010 - learning_rate: 3.0000e-04
# Epoch 4/60
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.6767 - loss: 0.8857
# Epoch 4: val_accuracy did not improve from 0.38095
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 363ms/step - accuracy: 0.7016 - loss: 0.8204 - val_accuracy: 0.3810 - val_loss: 1.1065 - learning_rate: 3.0000e-04
# Epoch 5/60
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.7687 - loss: 0.7206
# Epoch 5: val_accuracy did not improve from 0.38095
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 364ms/step - accuracy: 0.7672 - loss: 0.7215 - val_accuracy: 0.3810 - val_loss: 1.1122 - learning_rate: 3.0000e-04
# Epoch 6/60
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.7838 - loss: 0.6616
# Epoch 6: val_accuracy did not improve from 0.38095
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 14s 360ms/step - accuracy: 0.7875 - loss: 0.6984 - val_accuracy: 0.3636 - val_loss: 1.1327 - learning_rate: 3.0000e-04
# Epoch 7/60
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.7545 - loss: 0.6844
# Epoch 7: val_accuracy improved from 0.38095 to 0.43290, saving model to /content/drive/MyDrive/best_model.keras
#
# Epoch 7: finished saving model to /content/drive/MyDrive/best_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 372ms/step - accuracy: 0.7672 - loss: 0.6885 - val_accuracy: 0.4329 - val_loss: 1.1885 - learning_rate: 3.0000e-04
# Epoch 8/60
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.8005 - loss: 0.6627
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
#
# Epoch 8: val_accuracy did not improve from 0.43290
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 371ms/step - accuracy: 0.8016 - loss: 0.6857 - val_accuracy: 0.3983 - val_loss: 1.2359 - learning_rate: 3.0000e-04
# Epoch 9/60
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.8108 - loss: 0.6343
# Epoch 9: val_accuracy did not improve from 0.43290
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 366ms/step - accuracy: 0.8125 - loss: 0.6403 - val_accuracy: 0.3766 - val_loss: 1.2638 - learning_rate: 1.5000e-04
# Epoch 10/60
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.8256 - loss: 0.6508
# Epoch 10: val_accuracy did not improve from 0.43290
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 14s 361ms/step - accuracy: 0.8234 - loss: 0.6376 - val_accuracy: 0.4113 - val_loss: 1.2446 - learning_rate: 1.5000e-04
# Epoch 11/60
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.8477 - loss: 0.6124
# Epoch 11: val_accuracy did not improve from 0.43290
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 364ms/step - accuracy: 0.8453 - loss: 0.6133 - val_accuracy: 0.4026 - val_loss: 1.2989 - learning_rate: 1.5000e-04
# Epoch 12/60
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.8031 - loss: 0.6703
# Epoch 12: val_accuracy did not improve from 0.43290
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 368ms/step - accuracy: 0.8219 - loss: 0.6518 - val_accuracy: 0.4286 - val_loss: 1.2257 - learning_rate: 1.5000e-04
# Epoch 13/60
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.8308 - loss: 0.6740
# Epoch 13: val_accuracy improved from 0.43290 to 0.77922, saving model to /content/drive/MyDrive/best_model.keras
#
# Epoch 13: finished saving model to /content/drive/MyDrive/best_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 380ms/step - accuracy: 0.8359 - loss: 0.6292 - val_accuracy: 0.7792 - val_loss: 0.7402 - learning_rate: 1.5000e-04
# Epoch 14/60
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.8441 - loss: 0.6014
# Epoch 14: val_accuracy improved from 0.77922 to 0.83983, saving model to /content/drive/MyDrive/best_model.keras
#
# Epoch 14: finished saving model to /content/drive/MyDrive/best_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 368ms/step - accuracy: 0.8516 - loss: 0.5909 - val_accuracy: 0.8398 - val_loss: 0.6700 - learning_rate: 1.5000e-04
# Epoch 15/60
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.8470 - loss: 0.5868
# Epoch 15: val_accuracy improved from 0.83983 to 0.95671, saving model to /content/drive/MyDrive/best_model.keras
#
# Epoch 15: finished saving model to /content/drive/MyDrive/best_model.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 373ms/step - accuracy: 0.8453 - loss: 0.6089 - val_accuracy: 0.9567 - val_loss: 0.5297 - learning_rate: 1.5000e-04
# Epoch 16/60
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8416 - loss: 0.5840
# Epoch 16: val_accuracy did not improve from 0.95671
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 371ms/step - accuracy: 0.8547 - loss: 0.5823 - val_accuracy: 0.9221 - val_loss: 0.5498 - learning_rate: 1.5000e-04
# Epoch 17/60
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.8593 - loss: 0.5981
# Epoch 17: val_accuracy did not improve from 0.95671
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 381ms/step - accuracy: 0.8453 - loss: 0.6145 - val_accuracy: 0.9437 - val_loss: 0.5010 - learning_rate: 1.5000e-04
# Epoch 18/60
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.8674 - loss: 0.5669
# Epoch 18: val_accuracy did not improve from 0.95671
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 365ms/step - accuracy: 0.8391 - loss: 0.6262 - val_accuracy: 0.8831 - val_loss: 0.6071 - learning_rate: 1.5000e-04
# Epoch 19/60
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.8411 - loss: 0.6146
# Epoch 19: val_accuracy did not improve from 0.95671
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 367ms/step - accuracy: 0.8594 - loss: 0.5737 - val_accuracy: 0.9091 - val_loss: 0.5820 - learning_rate: 1.5000e-04
# Epoch 20/60
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.8480 - loss: 0.5758
# Epoch 20: val_accuracy did not improve from 0.95671
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 364ms/step - accuracy: 0.8328 - loss: 0.6013 - val_accuracy: 0.9048 - val_loss: 0.5706 - learning_rate: 1.5000e-04
# Epoch 21/60
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.8571 - loss: 0.6000
# Epoch 21: val_accuracy did not improve from 0.95671
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 365ms/step - accuracy: 0.8281 - loss: 0.6232 - val_accuracy: 0.9004 - val_loss: 0.6153 - learning_rate: 1.5000e-04
# Epoch 22/60
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.8846 - loss: 0.5297
# Epoch 22: val_accuracy did not improve from 0.95671
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 378ms/step - accuracy: 0.8641 - loss: 0.5725 - val_accuracy: 0.8874 - val_loss: 0.6078 - learning_rate: 1.5000e-04
# Epoch 23/60
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.8244 - loss: 0.6030
# Epoch 23: val_accuracy did not improve from 0.95671
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 367ms/step - accuracy: 0.8359 - loss: 0.5981 - val_accuracy: 0.9004 - val_loss: 0.6116 - learning_rate: 1.5000e-04
# Epoch 24/60
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.8403 - loss: 0.5984
# Epoch 24: ReduceLROnPlateau reducing learning rate to 7.500000356230885e-05.
#
# Epoch 24: val_accuracy did not improve from 0.95671
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 367ms/step - accuracy: 0.8469 - loss: 0.5876 - val_accuracy: 0.8701 - val_loss: 0.6370 - learning_rate: 1.5000e-04
# Epoch 25/60
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.8703 - loss: 0.6192
# Epoch 25: val_accuracy did not improve from 0.95671
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 363ms/step - accuracy: 0.8719 - loss: 0.5682 - val_accuracy: 0.8442 - val_loss: 0.6673 - learning_rate: 7.5000e-05
# Epoch 26/60
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.8734 - loss: 0.5454
# Epoch 26: val_accuracy did not improve from 0.95671
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 364ms/step - accuracy: 0.8703 - loss: 0.5560 - val_accuracy: 0.8918 - val_loss: 0.6189 - learning_rate: 7.5000e-05
# Epoch 27/60
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.8942 - loss: 0.5480
# Epoch 27: val_accuracy did not improve from 0.95671
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 381ms/step - accuracy: 0.8828 - loss: 0.5665 - val_accuracy: 0.8268 - val_loss: 0.6556 - learning_rate: 7.5000e-05
# Epoch 28/60
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.8215 - loss: 0.5756
# Epoch 28: val_accuracy did not improve from 0.95671
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 366ms/step - accuracy: 0.8469 - loss: 0.5734 - val_accuracy: 0.8831 - val_loss: 0.5943 - learning_rate: 7.5000e-05
# Epoch 29/60
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.8604 - loss: 0.5806
# Epoch 29: val_accuracy did not improve from 0.95671
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 364ms/step - accuracy: 0.8469 - loss: 0.5943 - val_accuracy: 0.8615 - val_loss: 0.6134 - learning_rate: 7.5000e-05
# Epoch 30/60
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.8681 - loss: 0.5727
# Epoch 30: val_accuracy did not improve from 0.95671
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 14s 362ms/step - accuracy: 0.8594 - loss: 0.5603 - val_accuracy: 0.8788 - val_loss: 0.6094 - learning_rate: 7.5000e-05
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 15.

# %%
model.save("/content/trained_modelff.keras")

with open("/content/training_hist.json", "w") as f:
    json.dump(history.history, f)

print("Saved!")
# Out:
# Saved!

# %%
epochs = range(1, len(history.history['accuracy']) + 1)

plt.figure(figsize=(10, 5))
plt.plot(epochs, history.history['accuracy'],     color='red',  label='Training Accuracy')
plt.plot(epochs, history.history['val_accuracy'], color='blue', label='Validation Accuracy')
plt.xlabel("No. of Epochs")
plt.ylabel("Accuracy Result")
plt.title("Visualization of Accuracy Result")
plt.legend(); plt.grid(True); plt.show()

plt.figure(figsize=(10, 5))
plt.plot(epochs, history.history['loss'],     color='red',  label='Training Loss')
plt.plot(epochs, history.history['val_loss'], color='blue', label='Validation Loss')
plt.xlabel("No. of Epochs")
plt.ylabel("Loss Result")
plt.title("Visualization of Loss Result")
plt.legend(); plt.grid(True); plt.show()

train_loss, train_acc = model.evaluate(train_gen, verbose=0)
val_loss,   val_acc   = model.evaluate(val_gen,   verbose=0)

print(f"Train → Loss: {train_loss:.4f} | Accuracy: {train_acc*100:.2f}%")
print(f"Val   → Loss: {val_loss:.4f}   | Accuracy: {val_acc*100:.2f}%")
# Out:
# Train → Loss: 0.6293 | Accuracy: 82.97%
# Val   → Loss: 0.5065   | Accuracy: 89.61%

# %%
test_gen = ImageDataGenerator(rescale=1./255).flow_from_directory(
    DATASET_PATH + "/test",
    target_size=IMG_SIZE,
    batch_size=32,
    class_mode='categorical',
    classes=CLASS_NAMES,
    shuffle=False
)

y_pred           = np.argmax(model.predict(test_gen, verbose=1), axis=1)
y_true           = test_gen.classes

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=CLASS_NAMES))
# Out:
# Found 177 images belonging to 3 classes.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step
#
# Classification Report:
#                   precision    recall  f1-score   support
#
#        Non-Tumor       0.97      0.78      0.87        91
# Non-Viable-Tumor       0.80      0.86      0.83        42
#           Viable       0.73      0.98      0.83        44
#
#         accuracy                           0.85       177
#        macro avg       0.83      0.87      0.84       177
#     weighted avg       0.87      0.85      0.85       177

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES,
            annot_kws={'size': 14})
plt.xlabel("Predicted Class", fontsize=14)
plt.ylabel("Actual Class",    fontsize=14)
plt.title("Osteosarcoma Detection Confusion Matrix", fontsize=13)
plt.tight_layout(); plt.show()

# %%
from tensorflow.keras.preprocessing import image as keras_image

def predict_image(img_path):
    img  = keras_image.load_img(img_path, target_size=IMG_SIZE)
    arr  = np.expand_dims(keras_image.img_to_array(img) / 255.0, 0)

    preds    = model.predict(arr, verbose=0)[0]
    pred_cls = CLASS_NAMES[np.argmax(preds)]
    conf     = np.max(preds) * 100

    plt.figure(figsize=(5, 5))
    plt.imshow(keras_image.load_img(img_path, target_size=IMG_SIZE))
    plt.title(f"Predicted: {pred_cls}  ({conf:.1f}%)", fontsize=13)
    plt.axis('off'); plt.show()


    for name, prob in zip(CLASS_NAMES, preds):
        print(f"  {name:<22} {prob*100:5.1f}%  {'█' * int(prob*20)}")


# Usage
predict_image("/content/dataset/test/Non-Tumor/Case-3-A15-18345-32676.jpg")

predict_image("/content/dataset/test/Non-Viable-Tumor/Case-3-A12-20939-18996.jpg")

predict_image("/content/dataset/test/Viable/Case-4-C27-32431-19828.jpg")
# Out:
#   Non-Tumor               92.3%  ██████████████████
#   Non-Viable-Tumor         4.7%
#   Viable                   3.0%
#   Non-Tumor                4.0%
#   Non-Viable-Tumor        94.3%  ██████████████████
#   Viable                   1.7%
#   Non-Tumor                1.5%
#   Non-Viable-Tumor         1.7%
#   Viable                  96.8%  ███████████████████
